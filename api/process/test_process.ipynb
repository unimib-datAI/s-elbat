# %%
import asyncio
import os
import sys
import time
import traceback

import redis
from keras.models import load_model

import utils.utils as utils
from phases.data_preparation import DataPreparation
from phases.featuresExtractionRevision import FeaturesExtractionRevision
from phases.feauturesExtraction import FeauturesExtraction
from phases.lookup import Lookup
from phases.prediction import Prediction
from phases.decision import Decision
from wrapper.lamAPI import LamAPI
from wrapper.Database import MongoDBWrapper  # MongoDB database wrapper




start = time.time()

pn_neural_path = "./ml_models/Linker_PN_100.h5"
rn_neural_path = "./ml_models/Linker_RN_100.h5"

pn_model = load_model(pn_neural_path)    
rn_model = load_model(rn_neural_path)    


REDIS_ENDPOINT = os.environ["REDIS_ENDPOINT"]
REDIS_JOB_DB = int(os.environ["REDIS_JOB_DB"])
LAMAPI_HOST = os.environ["LAMAPI_ENDPOINT"]
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]


job_active = redis.Redis(host=REDIS_ENDPOINT, db=REDIS_JOB_DB)

# Initialize MongoDB wrapper and get collections for different data models
mongoDBWrapper = MongoDBWrapper()
log_c = mongoDBWrapper.get_collection("log")
row_c = mongoDBWrapper.get_collection("row")
candidate_scored_c = mongoDBWrapper.get_collection("candidateScored")
cea_c = mongoDBWrapper.get_collection("cea")
cpa_c = mongoDBWrapper.get_collection("cpa")
cta_c = mongoDBWrapper.get_collection("cta")
cea_prelinking_c = mongoDBWrapper.get_collection("ceaPrelinking")

data = row_c.find_one({"tableName": "test_cb"})

if data is None:
    print("No data to process", flush=True)
    job_active.set("STOP", "")
    sys.exit(0)

rows_data = data["rows"]
kg_reference = data["kgReference"]
limit = data["candidateSize"]
column_metadata = data["column"]
target = data["target"]
_id = data["_id"]
dataset_name = data["datasetName"]
table_name = data["tableName"]
page = data["page"]
header = data["header"]

lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_TOKEN, mongoDBWrapper, kg=kg_reference)

obj_row_update = {"status": "DONE", "time": None}
dp = DataPreparation(header, rows_data, lamAPI)


column_metadata, target = await dp.compute_datatype(column_metadata, target)
column_metadata[str(target["SUBJ"])] = "SUBJ"
obj_row_update["column"] = column_metadata
obj_row_update["metadata"] = {
    "column": [{"idColumn": int(id_col), "tag": column_metadata[id_col]} for id_col in column_metadata]
}
obj_row_update["target"] = target
    
metadata = {
    "datasetName": dataset_name,
    "tableName": table_name,
    "kgReference": kg_reference,
    "page": page
}

collections = {
    "ceaPrelinking": cea_prelinking_c,
    "cea": cea_c,
    "cta": cta_c,
    "cpa": cpa_c,
    "candidateScored": candidate_scored_c
}
dp.rows_normalization()
l = Lookup(data, lamAPI, target, log_c, kg_reference, limit)
await l.generate_candidates()
rows = l.get_rows()
features = await FeauturesExtraction(rows, lamAPI).compute_feautures()
Prediction(rows, features, pn_model).compute_prediction("rho")
cea_preliking_data = utils.get_cea_pre_linking_data(metadata, rows)
revision = FeaturesExtractionRevision(rows)
features = revision.compute_features()
Prediction(rows, features, rn_model).compute_prediction("rho'")
storage = Decision(metadata, cea_preliking_data, rows, revision._cta, revision._cpa_pair, collections)
end = time.time()
execution_time = round(end - start, 2)
obj_row_update["time"] = execution_time
print("End", flush=True)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step
# End

# %%
l.get_rows()[3].get_cells()[4].content
# Out:
# 'kth royal insitute of technology'

# %%
l.get_rows()[3].get_cells()[4].candidates()

# %%
from keras.models import load_model

pn_neural_path = "./ml_models/Linker_PN.h5"
pn_model = load_model(pn_neural_path)
pn_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,676 (330.77 KB)
#  Trainable params: 84,674 (330.76 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
from keras.models import load_model

pn_neural_path = "./ml_models/Linker1.0_PN.h5"
pn_model = load_model(pn_neural_path)
pn_model.input_shape
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# (None, 29)

# %%
from keras.models import load_model

pn_neural_path = "./ml_models/Linker_RN.h5"
pn_model = load_model(pn_neural_path)
pn_model.input_shape
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# (None, 29)

# %%
import asyncio
import os
import sys
import time
import traceback

import redis
from keras.models import load_model

import utils.utils as utils
from phases.data_preparation import DataPreparation
from phases.featuresExtractionRevision import FeaturesExtractionRevision
from phases.feauturesExtraction import FeauturesExtraction
from phases.lookup import Lookup
from phases.prediction import Prediction
from phases.decision import Decision
from wrapper.lamAPI import LamAPI
from wrapper.Database import MongoDBWrapper  # MongoDB database wrapper




REDIS_ENDPOINT = os.environ["REDIS_ENDPOINT"]
REDIS_JOB_DB = int(os.environ["REDIS_JOB_DB"])
LAMAPI_HOST = os.environ["LAMAPI_ENDPOINT"]
LAMAPI_TOKEN = os.environ["LAMAPI_TOKEN"]



# Initialize MongoDB wrapper and get collections for different data models
mongoDBWrapper = MongoDBWrapper()
log_c = mongoDBWrapper.get_collection("log")
row_c = mongoDBWrapper.get_collection("row")
candidate_scored_c = mongoDBWrapper.get_collection("candidateScored")
cea_c = mongoDBWrapper.get_collection("cea")
cpa_c = mongoDBWrapper.get_collection("cpa")
cta_c = mongoDBWrapper.get_collection("cta")
cea_prelinking_c = mongoDBWrapper.get_collection("ceaPrelinking")
lamAPI = LamAPI(LAMAPI_HOST, LAMAPI_TOKEN, mongoDBWrapper, kg="crunchbase")
# Out:
# 2024-07-16 21:35:00.459204: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-16 21:35:00.561409: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-16 21:35:00.936229: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-16 21:35:02.101244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
await lamAPI.lookup(["facebook"])
# Out:
# [{'id': 'Q355',
#   'name': 'FACEBOOK',
#   'description': 'online social media and social networking service',
#   'types': [{'id': 'Q3220391', 'name': 'social networking service'},
#    {'id': 'Q35127', 'name': 'website'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.25,
#   'pos_score': 0.01,
#   'es_score': 1.0,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q380',
#   'name': 'Facebook',
#   'description': 'American social media and technology company',
#   'types': [{'id': 'Q783794', 'name': 'company'},
#    {'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q891723', 'name': 'public company'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.06,
#   'pos_score': 0.03,
#   'es_score': 0.979,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q5624646',
#   'name': 'Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.11,
#   'pos_score': 0.05,
#   'es_score': 0.977,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q116947',
#   'name': 'Facebook Bots',
#   'description': 'Messaging app and platform by Meta Platforms',
#   'types': [{'id': 'Q58199', 'name': 'instant messaging'},
#    {'id': 'Q35127', 'name': 'website'},
#    {'id': 'Q2462003', 'name': 'instant messaging client'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.06,
#   'pos_score': 0.16,
#   'es_score': 0.967,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.2},
#  {'id': 'Q6582413',
#   'name': 'Шаблон:User Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q20769160', 'name': 'Wikimedia userbox template'},
#    {'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 20,
#   'popularity': 0.04,
#   'pos_score': 0.31,
#   'es_score': 0.962,
#   'ed_score': 0.4,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.4,
#   'cosine_similarity': 0.11},
#  {'id': 'Q31963',
#   'name': 'Facebook Emoticons',
#   'description': 'pictorial representation of a facial expression using punctuation marks, numbers and letters',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.07,
#   'pos_score': 0.14,
#   'es_score': 0.968,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.22},
#  {'id': 'Q3242086',
#   'name': 'Facebook stalker',
#   'description': 'use of the Internet or other electronic means to stalk or harass an individual, a group, or an organization',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 16,
#   'popularity': 0.03,
#   'pos_score': 0.15,
#   'es_score': 0.968,
#   'ed_score': 0.5,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.55,
#   'cosine_similarity': 0.12},
#  {'id': 'Q108801995',
#   'name': 'Facebook outage',
#   'description': 'outage of Facebook, Instagram, WhatsApp, Oculus in October 2021',
#   'types': [{'id': 'Q28914147', 'name': 'outage'},
#    {'id': 'Q1656682', 'name': 'event'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.02,
#   'pos_score': 0.18,
#   'es_score': 0.966,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.13},
#  {'id': 'Q247213',
#   'name': 'Facebook pixel',
#   'description': 'method using server metrics for a served unobtrusive file to ascertain whether a page has been loaded and by whom',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.02,
#   'pos_score': 0.2,
#   'es_score': 0.966,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.16},
#  {'id': 'Q4734875',
#   'name': 'Facebook navbox',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.03,
#   'pos_score': 0.54,
#   'es_score': 0.959,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.18},
#  {'id': 'Q6328277',
#   'name': 'Catégorie:Jeu Facebook',
#   'description': 'Wikimedia Category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 22,
#   'popularity': 0.03,
#   'pos_score': 0.72,
#   'es_score': 0.955,
#   'ed_score': 0.36,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.35,
#   'cosine_similarity': 0.1},
#  {'id': 'Q2927074',
#   'name': 'Facebook meme',
#   'description': 'concept that spreads from person to person via the Internet',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.07,
#   'pos_score': 0.3,
#   'es_score': 0.963,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.24},
#  {'id': 'Q6965960',
#   'name': 'Kategori:Aplikasi Facebook',
#   'description': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 26,
#   'popularity': 0.01,
#   'pos_score': 0.668,
#   'es_score': 0.282,
#   'ed_score': 0.31,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.29,
#   'cosine_similarity': 0.18},
#  {'id': 'Q244752',
#   'name': 'Facebook divide',
#   'description': 'inequality of access to information and communication technologies',
#   'types': [{'id': 'Q5431887', 'name': 'social inequality'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.05,
#   'pos_score': 0.37,
#   'es_score': 0.962,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.18},
#  {'id': 'Q3274429',
#   'name': 'Facebook Rift',
#   'description': 'virtual reality headset by Facebook Technologies',
#   'types': [{'id': 'Q19600329', 'name': 'virtual reality headset'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.04,
#   'pos_score': 0.38,
#   'es_score': 0.962,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.22},
#  {'id': 'Q19878155',
#   'name': 'like Facebook',
#   'description': 'feature of the social networking website Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.58,
#   'es_score': 0.958,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.15},
#  {'id': 'Q25639070',
#   'name': 'Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.42,
#   'es_score': 0.961,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q19399674',
#   'name': 'Facebook React',
#   'description': 'JavaScript library for building user interfaces',
#   'types': [{'id': 'Q341', 'name': 'free software'},
#    {'id': 'Q1330336', 'name': 'web framework'},
#    {'id': 'Q188860', 'name': 'software library'},
#    {'id': 'Q783866', 'name': 'JavaScript library'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.04,
#   'pos_score': 0.43,
#   'es_score': 0.961,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.21},
#  {'id': 'Q185888',
#   'name': 'Facebook movie',
#   'description': '2010 film by David Fincher',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.08,
#   'pos_score': 0.44,
#   'es_score': 0.96,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.25},
#  {'id': 'Q64684932',
#   'name': 'Facebook Coin',
#   'description': 'digital currency proposed by Facebook',
#   'types': [{'id': 'Q13479982', 'name': 'cryptocurrency'},
#    {'id': 'Q193424', 'name': 'web service'},
#    {'id': 'Q341', 'name': 'free software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.04,
#   'pos_score': 0.81,
#   'es_score': 0.28,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.27},
#  {'id': 'Q267114',
#   'name': 'Facebook Marketing',
#   'description': 'use of social media platforms and websites to promote a product or service',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.04,
#   'pos_score': 0.47,
#   'es_score': 0.96,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.26},
#  {'id': 'Q3625572',
#   'name': 'Facebook app',
#   'description': "application platform around Facebook's social network",
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 12,
#   'popularity': 0.01,
#   'pos_score': 0.964,
#   'es_score': 0.279,
#   'ed_score': 0.67,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.86,
#   'cosine_similarity': 0.26},
#  {'id': 'Q45782118',
#   'name': 'Facebook TV',
#   'description': "Facebook's video-on-demand service",
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q35127', 'name': 'website'},
#    {'id': 'Q559856', 'name': 'online video platform'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 11,
#   'popularity': 0.02,
#   'pos_score': 0.84,
#   'es_score': 0.952,
#   'ed_score': 0.73,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 0.1},
#  {'id': 'Q3540279',
#   'name': 'facebook',
#   'description': 'directory of individuals in American universities',
#   'types': [{'id': 'Q756230', 'name': 'directory service'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.01,
#   'pos_score': 0.52,
#   'es_score': 0.959,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q59681050',
#   'name': 'Facebook addiction',
#   'description': 'A proposed medical diagnosis related to overuse of social media',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.01,
#   'pos_score': 0.62,
#   'es_score': 0.956,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.19},
#  {'id': 'Q82932',
#   'name': 'Facebook f8',
#   'description': 'mostly-annual conference held by Facebook, intended for developers and entrepreneurs',
#   'types': [{'id': 'Q625994', 'name': 'convention'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 11,
#   'popularity': 0.01,
#   'pos_score': 0.63,
#   'es_score': 0.956,
#   'ed_score': 0.73,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 0.11},
#  {'id': 'Q5428461',
#   'name': 'Facebook diplomacy',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.01,
#   'pos_score': 0.496,
#   'es_score': 0.284,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.19},
#  {'id': 'Q3002982',
#   'name': 'Facebook criticism',
#   'description': "media coverage of the shortcomings of Facebook's market dominance",
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.01,
#   'pos_score': 0.67,
#   'es_score': 0.956,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.24},
#  {'id': 'Q1041225',
#   'name': 'Facebook game',
#   'description': 'video game genre',
#   'types': [{'id': 'Q659563', 'name': 'video game genre'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.588,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.17},
#  {'id': 'Q7212752',
#   'name': 'Kategori:Pengguna Facebook',
#   'description': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 26,
#   'popularity': 0.01,
#   'pos_score': 0.79,
#   'es_score': 0.954,
#   'ed_score': 0.31,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.29,
#   'cosine_similarity': 0.14},
#  {'id': 'Q266134',
#   'name': 'Facebook wall',
#   'description': 'Wikimedia list article',
#   'types': [{'id': 'Q13406463', 'name': 'Wikimedia list article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.92,
#   'es_score': 0.951,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.13},
#  {'id': 'Q7205250',
#   'name': 'Kategori:Karyawan Facebook',
#   'description': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 26,
#   'popularity': 0.01,
#   'pos_score': 0.8,
#   'es_score': 0.953,
#   'ed_score': 0.31,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.29,
#   'cosine_similarity': 0.15},
#  {'id': 'Q1140126',
#   'name': 'Facebook Analytics',
#   'description': 'process of gathering and analyzing data from social media',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.02,
#   'pos_score': 0.81,
#   'es_score': 0.953,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.17},
#  {'id': 'Q10920',
#   'name': 'Operation Facebook',
#   'description': 'decentralized, internet-based protest movement which organizes cyber attacks and demonstrations for freedom and against various forms of grievance',
#   'types': [{'id': 'Q2801262', 'name': 'hacker group'},
#    {'id': 'Q49773', 'name': 'social movement'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.08,
#   'pos_score': 0.82,
#   'es_score': 0.953,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.1},
#  {'id': 'Q109647710',
#   'name': 'Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.85,
#   'es_score': 0.952,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q28135300',
#   'name': 'Facebook Workplace',
#   'description': 'collaboration software',
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q210980', 'name': 'virtual community'},
#    {'id': 'Q7397', 'name': 'software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.01,
#   'pos_score': 0.86,
#   'es_score': 0.952,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.5,
#   'cosine_similarity': 0.16},
#  {'id': 'Q1668020',
#   'name': 'Facebook scam',
#   'description': 'type of fraud or deception which makes use of the Internet to defraud victims',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.02,
#   'pos_score': 0.88,
#   'es_score': 0.951,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.16},
#  {'id': 'Q59779876',
#   'name': 'Facebook Portal',
#   'description': 'line of smart displays by Facebook',
#   'types': [{'id': 'Q2424752', 'name': 'product'},
#    {'id': 'Q431289', 'name': 'brand'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.01,
#   'pos_score': 0.526,
#   'es_score': 0.284,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.22},
#  {'id': 'Q26450992',
#   'name': 'Facebook Story',
#   'description': '2016 album by Frank Ocean',
#   'types': [{'id': 'Q482994', 'name': 'album'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.02,
#   'pos_score': 0.95,
#   'es_score': 0.95,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.13},
#  {'id': 'Q1068450',
#   'name': 'Facebook (song)',
#   'description': '2012 song by Valentina Monetta',
#   'types': [{'id': 'Q134556', 'name': 'single'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.02,
#   'pos_score': 0.96,
#   'es_score': 0.95,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.18},
#  {'id': 'Q16927692',
#   'name': 'Facebook Zero',
#   'description': 'zero-rated Facebook mobile website',
#   'types': [{'id': 'Q35127', 'name': 'website'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.99,
#   'es_score': 0.95,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.12},
#  {'id': 'Q18613161',
#   'name': 'Facebook',
#   'description': '300th strip of the webcomic xkcd',
#   'types': [{'id': 'Q838795', 'name': 'comic strip'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.298,
#   'es_score': 0.295,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'P2013',
#   'name': 'Facebook',
#   'description': "identifier for an official (preferably) Facebook person, product or organization page (everything that follows URL part 'https://www.facebook.com/')",
#   'types': [{'id': 'Q105388954',
#     'name': 'Wikidata property to identify online accounts'},
#    {'id': 'Q24239898', 'name': 'Wikidata property for Wikivoyage listings'},
#    {'id': 'Q62589320',
#     'name': 'Wikidata property for an identifier that does not imply notability'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.3,
#   'es_score': 0.294,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q19790218',
#   'name': 'Facebook',
#   'description': 'Wikinews article',
#   'types': [{'id': 'Q17633526', 'name': 'Wikinews article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.304,
#   'es_score': 0.291,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q17876930',
#   'name': 'Facebook',
#   'description': 'Wikinews article',
#   'types': [{'id': 'Q17633526', 'name': 'Wikinews article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.306,
#   'es_score': 0.289,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q16238453',
#   'name': 'Facebook',
#   'description': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.31,
#   'es_score': 0.289,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q108926046',
#   'name': 'FACEBOOK',
#   'description': 'scholarly article by Andréa Karla Ferreira Nunes et al published 8 July 2021 in Revista Extensão em Ação',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.316,
#   'es_score': 0.288,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q106714180',
#   'name': 'facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.318,
#   'es_score': 0.288,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'P4003',
#   'name': 'Facebook',
#   'description': 'official Facebook page of this entity (only for use with URLs containing "/pages/")',
#   'types': [{'id': 'Q105388954',
#     'name': 'Wikidata property to identify online accounts'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 1,
#   'length_mention': 8,
#   'length_entity': 8,
#   'popularity': 0.0,
#   'pos_score': 0.32,
#   'es_score': 0.288,
#   'ed_score': 1.0,
#   'jaccard_score': 1.0,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 1.0},
#  {'id': 'Q88008554',
#   'name': 'konto Facebook',
#   'description': 'user account on Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.332,
#   'es_score': 0.287,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.16},
#  {'id': 'Q101420143',
#   'name': 'Facebook page',
#   'description': 'pages on Facebook are dedicated to businesses, brands, organizations and public figures',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.344,
#   'es_score': 0.286,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.17},
#  {'id': 'Q108926879',
#   'name': 'Friendless Facebook',
#   'description': 'scholarly article by Sarah Sands published April 2021 in Index on censorship',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 19,
#   'popularity': 0.0,
#   'pos_score': 0.348,
#   'es_score': 0.286,
#   'ed_score': 0.42,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.43,
#   'cosine_similarity': 0.17},
#  {'id': 'Q16927686',
#   'name': 'Facebook Paper',
#   'description': 'defunct news portal, released 2014',
#   'types': [{'id': 'Q7397', 'name': 'software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.35,
#   'es_score': 0.286,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.18},
#  {'id': 'Q58814026',
#   'name': 'Facebook City',
#   'description': 'headquarters campus of Meta and its Facebook subsidiary in Menlo Park, California, United States; former Sun Microsystems headquarters',
#   'types': [{'id': 'Q1021645', 'name': 'office building'},
#    {'id': 'Q209465', 'name': 'campus'},
#    {'id': 'Q7540126', 'name': 'headquarters'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.362,
#   'es_score': 0.286,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.25},
#  {'id': 'Q48814289',
#   'name': 'Facebook worm',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.73,
#   'es_score': 0.281,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.21},
#  {'id': 'Q16972122',
#   'name': 'Facebook Purity',
#   'description': 'web browser extension',
#   'types': [{'id': 'Q166142', 'name': 'application'},
#    {'id': 'Q5583816', 'name': 'Google Chrome extension'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.376,
#   'es_score': 0.286,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.24},
#  {'id': 'Q5058941',
#   'name': 'Facebook ban',
#   'description': 'history of censorship and limitation of Facebook throughout the world',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 12,
#   'popularity': 0.01,
#   'pos_score': 0.452,
#   'es_score': 0.285,
#   'ed_score': 0.67,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.86,
#   'cosine_similarity': 0.13},
#  {'id': 'Q7612603',
#   'name': 'Facebook Ads',
#   'description': 'Facebook Advertising is comprised of various advertising methods via the social network Facebook.',
#   'types': [{'id': 'Q1668024', 'name': 'service on internet'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 12,
#   'popularity': 0.0,
#   'pos_score': 0.382,
#   'es_score': 0.285,
#   'ed_score': 0.67,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.86,
#   'cosine_similarity': 0.25},
#  {'id': 'Q98076236',
#   'name': 'Facebook Konum',
#   'description': 'location-publicising service',
#   'types': [{'id': 'Q7406919', 'name': 'service'},
#    {'id': 'Q386724', 'name': 'work'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.386,
#   'es_score': 0.285,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.1},
#  {'id': 'Q108254654',
#   'name': 'Facebook Viewpoints',
#   'description': 'mobile app',
#   'types': [{'id': 'Q620615', 'name': 'mobile app'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 19,
#   'popularity': 0.0,
#   'pos_score': 0.388,
#   'es_score': 0.285,
#   'ed_score': 0.42,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.43,
#   'cosine_similarity': 0.11},
#  {'id': 'Q28057499',
#   'name': 'Facebook Gameroom',
#   'description': 'video game distribution platform',
#   'types': [{'id': 'Q81989119', 'name': 'video game distribution platform'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 17,
#   'popularity': 0.0,
#   'pos_score': 0.392,
#   'es_score': 0.285,
#   'ed_score': 0.47,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.5,
#   'cosine_similarity': 0.16},
#  {'id': 'Q26026957',
#   'name': 'Modèle:Compte Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 22,
#   'popularity': 0.0,
#   'pos_score': 0.394,
#   'es_score': 0.285,
#   'ed_score': 0.36,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.35,
#   'cosine_similarity': 0.08},
#  {'id': 'Q3679366',
#   'name': 'Facebook Lite',
#   'description': 'Aspect of history of the Internet',
#   'types': [{'id': 'Q50309095', 'name': 'history of an organization'},
#    {'id': 'Q17524420', 'name': 'aspect of history'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.582,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.12},
#  {'id': 'Q88537331',
#   'name': 'facebook lraq',
#   'description': 'corporation incorporated according to Delaware law',
#   'types': [{'id': 'Q57653825', 'name': 'type of business entity in the USA'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.412,
#   'es_score': 0.285,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.17},
#  {'id': 'Q97959542',
#   'name': 'Facebook Room',
#   'description': 'A videoconferencing extension of Facebook Messenger',
#   'types': [{'id': 'Q7397', 'name': 'software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.434,
#   'es_score': 0.285,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.27},
#  {'id': 'Q109393642',
#   'name': 'Facebook Events',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.438,
#   'es_score': 0.285,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.21},
#  {'id': 'P1997',
#   'name': 'Facebook Places',
#   'description': 'identifier for a place in Facebook',
#   'types': [{'id': 'Q19829908',
#     'name': 'Wikidata property for authority control for places'},
#    {'id': 'Q30041186',
#     'name': 'Wikidata property related to online communities'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.448,
#   'es_score': 0.285,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.23},
#  {'id': 'Q28051400',
#   'name': 'Facebook Live',
#   'description': 'live streaming service',
#   'types': [{'id': 'Q102336293', 'name': 'live streaming service'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.454,
#   'es_score': 0.285,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.12},
#  {'id': 'Q21685563',
#   'name': 'Facebook group',
#   'description': 'online community on Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.458,
#   'es_score': 0.285,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.17},
#  {'id': 'Q29123981',
#   'name': 'Facebook (Israel)',
#   'description': '',
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q6881511', 'name': 'enterprise'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 17,
#   'popularity': 0.0,
#   'pos_score': 0.46,
#   'es_score': 0.285,
#   'ed_score': 0.47,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.5,
#   'cosine_similarity': 0.14},
#  {'id': 'Q3234817',
#   'name': 'Facebook beacon',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.466,
#   'es_score': 0.285,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.24},
#  {'id': 'Q5428465',
#   'name': 'Statistik Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.0,
#   'pos_score': 0.472,
#   'es_score': 0.284,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.14},
#  {'id': 'Q19865830',
#   'name': 'Facebook Study',
#   'description': 'Israeli mobile web analytics company owned by Facebook',
#   'types': [{'id': 'Q4830453', 'name': 'business'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.478,
#   'es_score': 0.284,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.13},
#  {'id': 'Q7604532',
#   'name': 'Facebook status',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.48,
#   'es_score': 0.284,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.11},
#  {'id': 'Q2525682',
#   'name': 'Facebook murder',
#   'description': '2012 murder of Joyce (Winsie) Hau, by the then 14–year-old Jinhua K. from Capelle aan den IJssel, in the Netherlands',
#   'types': [{'id': 'Q132821', 'name': 'murder'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.488,
#   'es_score': 0.284,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.24},
#  {'id': 'Q29439733',
#   'name': 'Facebook murder',
#   'description': 'shooting in Cleveland, OH, USA',
#   'types': [{'id': 'Q132821', 'name': 'murder'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.01,
#   'pos_score': 0.492,
#   'es_score': 0.284,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.24},
#  {'id': 'Q86674219',
#   'name': 'Эксперимент Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 20,
#   'popularity': 0.0,
#   'pos_score': 0.5,
#   'es_score': 0.284,
#   'ed_score': 0.4,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.4,
#   'cosine_similarity': 0.09},
#  {'id': 'Q109313220',
#   'name': 'Facebook acquisitions',
#   'description': 'Wikimedia list article',
#   'types': [{'id': 'Q13406463', 'name': 'Wikimedia list article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 21,
#   'popularity': 0.0,
#   'pos_score': 0.502,
#   'es_score': 0.284,
#   'ed_score': 0.38,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.38,
#   'cosine_similarity': 0.15},
#  {'id': 'Q110227923',
#   'name': 'Facebook website',
#   'description': 'website of the social networking platform Facebook',
#   'types': [{'id': 'Q35127', 'name': 'website'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 16,
#   'popularity': 0.0,
#   'pos_score': 0.504,
#   'es_score': 0.284,
#   'ed_score': 0.5,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.55,
#   'cosine_similarity': 0.24},
#  {'id': 'Q20064379',
#   'name': 'Vorlog:Ausruaf Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 23,
#   'popularity': 0.0,
#   'pos_score': 0.88,
#   'es_score': 0.279,
#   'ed_score': 0.35,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.33,
#   'cosine_similarity': 0.1},
#  {'id': 'Q63976443',
#   'name': 'profil Facebook',
#   'description': 'user profile on Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.714,
#   'es_score': 0.281,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.12},
#  {'id': 'Q5428462',
#   'name': 'Facebook Revolution',
#   'description': 'Wikimedia disambiguation page',
#   'types': [{'id': 'Q4167410', 'name': 'Wikimedia disambiguation page'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 19,
#   'popularity': 0.0,
#   'pos_score': 0.512,
#   'es_score': 0.284,
#   'ed_score': 0.42,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.43,
#   'cosine_similarity': 0.26},
#  {'id': 'Q30324162',
#   'name': 'Facebook propaganda',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 19,
#   'popularity': 0.0,
#   'pos_score': 0.524,
#   'es_score': 0.284,
#   'ed_score': 0.42,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.43,
#   'cosine_similarity': 0.15},
#  {'id': 'Q8442203',
#   'name': 'Categoria:Gruppi Facebook',
#   'description': 'Wikimedia category',
#   'types': [{'id': 'Q4167836', 'name': 'Wikimedia category'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 25,
#   'popularity': 0.01,
#   'pos_score': 0.534,
#   'es_score': 0.284,
#   'ed_score': 0.32,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.3,
#   'cosine_similarity': 0.12},
#  {'id': 'Q21825447',
#   'name': 'Happy Facebook',
#   'description': '2016 South Korean film',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.01,
#   'pos_score': 0.536,
#   'es_score': 0.284,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.12},
#  {'id': 'Q5428453',
#   'name': 'Kredit Facebook',
#   'description': 'Amarbegarbaa',
#   'types': [{'id': 'Q5428461', 'name': 'Facebook diplomacy'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.01,
#   'pos_score': 0.594,
#   'es_score': 0.283,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.11},
#  {'id': 'Q28039995',
#   'name': 'Facebook City',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.54,
#   'es_score': 0.284,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.25},
#  {'id': 'Q28502405',
#   'name': 'Facebook Blueprint',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.0,
#   'pos_score': 0.542,
#   'es_score': 0.284,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.14},
#  {'id': 'Q108800322',
#   'name': 'Facebook Files',
#   'description': 'Internal document leak from Facebook',
#   'types': [{'id': 'Q49848', 'name': 'document'},
#    {'id': 'Q2904148', 'name': 'information leak'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.592,
#   'es_score': 0.283,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.16},
#  {'id': 'Q48996266',
#   'name': 'Facebook Infer',
#   'description': '',
#   'types': [{'id': 'Q28061130', 'name': 'static program analysis tool'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.56,
#   'es_score': 0.284,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.17},
#  {'id': 'Q9257634',
#   'name': 'Facebook Connect',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 16,
#   'popularity': 0.0,
#   'pos_score': 0.566,
#   'es_score': 0.284,
#   'ed_score': 0.5,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.55,
#   'cosine_similarity': 0.23},
#  {'id': 'Q19727306',
#   'name': 'Kartu Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.57,
#   'es_score': 0.283,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.21},
#  {'id': 'Q13179656',
#   'name': 'Facebook Zero',
#   'description': 'Nepalese telecommunications company',
#   'types': [{'id': 'Q2401749', 'name': 'telecommunication company'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.584,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.12},
#  {'id': 'Q108298380',
#   'name': 'Facebook Mama',
#   'description': "journal article from 'WSQ: Women's Studies Quarterly' published in 2019",
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.586,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.26},
#  {'id': 'Q85336683',
#   'name': 'Facebook like',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.602,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.11},
#  {'id': 'Q12513915',
#   'name': 'Setan Facebook',
#   'description': '2010 film',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.606,
#   'es_score': 0.283,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.13},
#  {'id': 'Q2293677',
#   'name': 'Millat Facebook',
#   'description': '',
#   'types': [{'id': 'Q35127', 'name': 'website'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.01,
#   'pos_score': 0.61,
#   'es_score': 0.283,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.13},
#  {'id': 'Q18149779',
#   'name': 'Facebook Slingshot',
#   'description': '',
#   'types': [{'id': 'Q7397', 'name': 'software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.01,
#   'pos_score': 0.612,
#   'es_score': 0.283,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.11},
#  {'id': 'Q48802942',
#   'name': 'Facebook アクイラ',
#   'description': 'experimental solar-powered drone',
#   'types': [{'id': 'Q484000', 'name': 'unmanned aerial vehicle'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.62,
#   'es_score': 0.283,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.27},
#  {'id': 'Q106143158',
#   'name': 'Facebook Horizon',
#   'description': 'online video game',
#   'types': [{'id': 'Q7889', 'name': 'video game'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
# ...
#   'name': 'Facebook Notes',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.794,
#   'es_score': 0.28,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.16},
#  {'id': 'Q107392606',
#   'name': 'Oculus do Facebook',
#   'description': 'brand of virtual reality hardware and software',
#   'types': [{'id': 'Q431289', 'name': 'brand'},
#    {'id': 'Q167270', 'name': 'trademark'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.02,
#   'pos_score': 0.798,
#   'es_score': 0.28,
#   'ed_score': 0.44,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.21},
#  {'id': 'Q6485469',
#   'name': 'Facebook Beacon Case',
#   'description': '',
#   'types': [{'id': 'Q2783852', 'name': 'class action'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 20,
#   'popularity': 0.0,
#   'pos_score': 0.802,
#   'es_score': 0.28,
#   'ed_score': 0.4,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.5,
#   'cosine_similarity': 0.27},
#  {'id': 'Q20568694',
#   'name': 'Функци во Facebook',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.0,
#   'pos_score': 0.806,
#   'es_score': 0.28,
#   'ed_score': 0.44,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.09},
#  {'id': 'Q108254325',
#   'name': 'Facebook Study',
#   'description': 'Android app',
#   'types': [{'id': 'Q620615', 'name': 'mobile app'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.812,
#   'es_score': 0.28,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.13},
#  {'id': 'Q29453067',
#   'name': 'Facebook M',
#   'description': 'discontinued virtual assistant by Facebook',
#   'types': [{'id': 'Q3467906', 'name': 'virtual assistant'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 10,
#   'popularity': 0.01,
#   'pos_score': 0.816,
#   'es_score': 0.28,
#   'ed_score': 0.8,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 1.0,
#   'cosine_similarity': 0.36},
#  {'id': 'Q61058404',
#   'name': 'Facebook Pixel',
#   'description': 'Pixel product of Facebook Inc',
#   'types': [{'id': 'Q1668024', 'name': 'service on internet'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 14,
#   'popularity': 0.0,
#   'pos_score': 0.832,
#   'es_score': 0.28,
#   'ed_score': 0.57,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.16},
#  {'id': 'Q91201681',
#   'name': 'Facebook Gaming',
#   'description': 'official application for Android devices developed by Facebook',
#   'types': [{'id': 'Q620615', 'name': 'mobile app'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.836,
#   'es_score': 0.28,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.19},
#  {'id': 'Q55973596',
#   'name': 'Facebook Dating',
#   'description': 'digital dating product',
#   'types': [{'id': 'Q35127', 'name': 'website'},
#    {'id': 'Q612825', 'name': 'online dating service'},
#    {'id': 'Q3220391', 'name': 'social networking service'},
#    {'id': 'Q2462003', 'name': 'instant messaging client'},
#    {'id': 'Q28134845', 'name': 'dating app'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.01,
#   'pos_score': 0.838,
#   'es_score': 0.28,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.18},
#  {'id': 'Q58819283',
#   'name': 'Facing Facebook',
#   'description': 'scholarly article by Ella Lillqvist & Leena Louhiala-Salminen published 26 September 2013 in Journal of Business and Technical Communication',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.84,
#   'es_score': 0.28,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.11},
#  {'id': 'Q107207471',
#   'name': 'Facebook followers',
#   'description': 'Facebook users who has chosen to receive the updates that followed user post in their feed',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.0,
#   'pos_score': 0.848,
#   'es_score': 0.28,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.16},
#  {'id': 'Q10630551',
#   'name': 'Facebook Home',
#   'description': 'user interface layer for Android-compatible smartphones',
#   'types': [{'id': 'Q7397', 'name': 'software'},
#    {'id': 'Q47146', 'name': 'user interface'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.01,
#   'pos_score': 0.85,
#   'es_score': 0.28,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.24},
#  {'id': 'Q7067518',
#   'name': 'Facebook Yarn',
#   'description': 'Package manager for the Node.js JavaScript runtime environment',
#   'types': [{'id': 'Q98400282', 'name': 'application-level package manager'},
#    {'id': 'Q341', 'name': 'free software'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.03,
#   'pos_score': 0.854,
#   'es_score': 0.279,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.22},
#  {'id': 'Q20714579',
#   'name': 'Facebook Instant',
#   'description': 'feature of the social networking website Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 16,
#   'popularity': 0.01,
#   'pos_score': 0.856,
#   'es_score': 0.279,
#   'ed_score': 0.5,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.55,
#   'cosine_similarity': 0.19},
#  {'id': 'Q10767727',
#   'name': 'Facebook Effect',
#   'description': 'book by David Kirkpatrick',
#   'types': [{'id': 'Q7725634', 'name': 'literary work'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.866,
#   'es_score': 0.279,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.22},
#  {'id': 'Q5428456',
#   'name': 'Facebook IPO',
#   'description': 'IPO of Facebook Inc.',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 12,
#   'popularity': 0.0,
#   'pos_score': 0.868,
#   'es_score': 0.279,
#   'ed_score': 0.67,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.86,
#   'cosine_similarity': 0.19},
#  {'id': 'Q104717411',
#   'name': 'Facebook post',
#   'description': 'individual entry on Facebook',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 13,
#   'popularity': 0.0,
#   'pos_score': 0.87,
#   'es_score': 0.279,
#   'ed_score': 0.62,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.75,
#   'cosine_similarity': 0.26},
#  {'id': 'Q95937163',
#   'name': 'The relationship between narcissism, intensity of Facebook use, Facebook flow and Facebook addiction',
#   'description': 'scientific article published on 21 February 2020',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 13,
#   'length_mention': 8,
#   'length_entity': 100,
#   'popularity': 0.0,
#   'pos_score': 0.872,
#   'es_score': 0.279,
#   'ed_score': 0.08,
#   'jaccard_score': 0.09,
#   'jaccardNgram_score': 0.12,
#   'cosine_similarity': 0.13},
#  {'id': 'Q17876958',
#   'name': 'Facebook купил WhatsApp',
#   'description': 'Wikinews article',
#   'types': [{'id': 'Q17633526', 'name': 'Wikinews article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 23,
#   'popularity': 0.0,
#   'pos_score': 0.894,
#   'es_score': 0.279,
#   'ed_score': 0.35,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.4,
#   'cosine_similarity': 0.12},
#  {'id': 'Q61058375',
#   'name': 'Facebook Ireland Limited',
#   'description': 'Irish subsidiary of Facebook Inc',
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q6881511', 'name': 'enterprise'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 24,
#   'popularity': 0.0,
#   'pos_score': 0.904,
#   'es_score': 0.279,
#   'ed_score': 0.33,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.38,
#   'cosine_similarity': 0.14},
#  {'id': 'Q108925801',
#   'name': 'Facebook Über Alles',
#   'description': 'scientific article',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 19,
#   'popularity': 0.0,
#   'pos_score': 0.912,
#   'es_score': 0.279,
#   'ed_score': 0.42,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.55,
#   'cosine_similarity': 0.18},
#  {'id': 'Q22908312',
#   'name': 'Facebook privacy hoax',
#   'description': '',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 21,
#   'popularity': 0.0,
#   'pos_score': 0.914,
#   'es_score': 0.279,
#   'ed_score': 0.38,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.12},
#  {'id': 'Q16321326',
#   'name': 'Facebook Technologies',
#   'description': 'American virtual reality technology company',
#   'types': [{'id': 'Q4830453', 'name': 'business'},
#    {'id': 'Q658255', 'name': 'subsidiary'},
#    {'id': 'Q6881511', 'name': 'enterprise'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 21,
#   'popularity': 0.0,
#   'pos_score': 0.98,
#   'es_score': 0.279,
#   'ed_score': 0.38,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.38,
#   'cosine_similarity': 0.16},
#  {'id': 'Q97166268',
#   'name': 'Facebook Marketing',
#   'description': 'Refers to creating, using Facebook page as a communications channel to maintain contact with and attract customers, allowing users to create business pages for companies, organizations to develop a fan base for a product, service, or brand.',
#   'types': [],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 18,
#   'popularity': 0.0,
#   'pos_score': 0.93,
#   'es_score': 0.279,
#   'ed_score': 0.44,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.46,
#   'cosine_similarity': 0.26},
#  {'id': 'Q39256837',
#   'name': 'Facebook friend',
#   'description': 'scientific article',
#   'types': [{'id': 'Q13442814', 'name': 'scholarly article'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.96,
#   'es_score': 0.279,
#   'ed_score': 0.53,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.6,
#   'cosine_similarity': 0.18},
#  {'id': 'Q43373366',
#   'name': 'Farewell Facebook',
#   'description': '2010 Dutch documentary film',
#   'types': [{'id': 'Q11424', 'name': 'film'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 17,
#   'popularity': 0.0,
#   'pos_score': 0.962,
#   'es_score': 0.279,
#   'ed_score': 0.47,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.5,
#   'cosine_similarity': 0.19},
#  {'id': 'Q14400757',
#   'name': 'Templat:Laman Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 22,
#   'popularity': 0.02,
#   'pos_score': 0.972,
#   'es_score': 0.279,
#   'ed_score': 0.36,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.35,
#   'cosine_similarity': 0.1},
#  {'id': 'Q19928848',
#   'name': 'Шаблон:Зростання Facebook',
#   'description': 'Wikimedia template',
#   'types': [{'id': 'Q11266439', 'name': 'Wikimedia template'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 2,
#   'length_mention': 8,
#   'length_entity': 25,
#   'popularity': 0.0,
#   'pos_score': 0.982,
#   'es_score': 0.279,
#   'ed_score': 0.32,
#   'jaccard_score': 0.5,
#   'jaccardNgram_score': 0.3,
#   'cosine_similarity': 0.13},
#  {'id': 'Q104132249',
#   'name': 'FTC v. Facebook',
#   'description': '2020 lawsuit',
#   'types': [{'id': 'Q61221204', 'name': 'antitrust case'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 15,
#   'popularity': 0.0,
#   'pos_score': 0.986,
#   'es_score': 0.278,
#   'ed_score': 0.53,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.86,
#   'cosine_similarity': 0.1},
#  {'id': 'Q209330',
#   'name': 'Instagram from Facebook',
#   'description': 'online photo-sharing and social networking service owned by Meta, Inc.',
#   'types': [{'id': 'Q620615', 'name': 'mobile app'},
#    {'id': 'Q3220391', 'name': 'social networking service'},
#    {'id': 'Q35127', 'name': 'website'},
#    {'id': 'Q2721136', 'name': 'image hosting service'},
#    {'id': 'Q559856', 'name': 'online video platform'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 23,
#   'popularity': 0.14,
#   'pos_score': 0.99,
#   'es_score': 0.278,
#   'ed_score': 0.35,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.4,
#   'cosine_similarity': 0.17},
#  {'id': 'Q78902505',
#   'name': 'Facebook för alla',
#   'description': 'Swedish periodical',
#   'types': [{'id': 'Q1002697', 'name': 'periodical'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 17,
#   'popularity': 0.0,
#   'pos_score': 0.994,
#   'es_score': 0.278,
#   'ed_score': 0.47,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.12},
#  {'id': 'Q7450140',
#   'name': 'Amici di Facebook',
#   'description': 'episode of Modern Family',
#   'types': [{'id': 'Q21191270', 'name': 'television series episode'}],
#   'ambiguity_mention': 0.241,
#   'corrects_tokens': 1.0,
#   'ntoken_mention': 1,
#   'ntoken_entity': 3,
#   'length_mention': 8,
#   'length_entity': 17,
#   'popularity': 0.0,
#   'pos_score': 1.0,
#   'es_score': 0.278,
#   'ed_score': 0.47,
#   'jaccard_score': 0.33,
#   'jaccardNgram_score': 0.67,
#   'cosine_similarity': 0.12}]

# %%
await lamAPI.labels(["Q5"])
# Out:
# {'Q5': {'kind': 'type',
#   'NERtype': 'OTHERS',
#   'url': 'https://www.wikidata.org/wiki/Q5',
#   'description': 'any member of Homo sapiens, unique extant species of the genus Homo, from embryo to adult',
#   'labels': {'en': 'human'},
#   'aliases': {'en': ['people',
#     'humans',
#     'men',
#     'non-fictional human',
#     'individual human',
#     'man',
#     'person',
#     'nonfictional human',
#     'human being',
#     'individual Homo sapien']}}}

# %%
lamAPI.labels
# Out:
# <bound method LamAPI.labels of <wrapper.lamAPI.LamAPI object at 0xffff1dbd1a90>>

# %%
column
# Out:
# '5'

# %%
result["winningCandidates"]["0"]

# %%
from collections import defaultdict

# Initialize dictionaries to aggregate results and count occurrences
aggregated_winning_candidates = defaultdict(lambda: defaultdict(float))
candidate_counts = defaultdict(lambda: defaultdict(int))

# Fetch documents from the collection
documents = cta_c.find({"datasetName": "test", "tableName": "film"})

# Aggregate winning candidates and count occurrences
for doc in documents:
    winning_candidates = doc.get("winningCandidates", {})
    for key, candidates in winning_candidates.items():
        for candidate, score in candidates.items():
            aggregated_winning_candidates[key][candidate] += score
            candidate_counts[key][candidate] += 1

# Normalize the aggregated scores by the number of occurrences
normalized_winning_candidates = {}
for key, candidates in aggregated_winning_candidates.items():
    normalized_winning_candidates[key] = {candidate: round(score / candidate_counts[key][candidate], 3) for candidate, score in candidates.items()}

qids_types = set()
column_to_types = {}
for column in normalized_winning_candidates:
    top_10_types = sorted(normalized_winning_candidates[column].items(), key=lambda x: x[1], reverse=True)[0:10]
    column_to_types[column] = {}
    for k, v in top_10_types:
        column_to_types[column][k] = v 
        qids_types.add(k)
        
qids_to_labels = await lamAPI.labels(list(qids_types))
new_column_to_types = {}
for column in column_to_types:
    new_column_to_types[column] = [] 
    for k, v in column_to_types[column].items():
        new_column_to_types[column].append({"id": k, "label": qids_to_labels[k]["labels"].get("en"), "score": v})

# %%
from collections import defaultdict
import asyncio

async def fetch_labels(qids):
    return await lamAPI.labels(qids)
    

# Initialize dictionaries to aggregate results and count occurrences
aggregated_winning_predicates = defaultdict(lambda: defaultdict(float))
predicate_counts = defaultdict(lambda: defaultdict(int))

# Fetch documents from the collection
documents = cpa_c.find({"datasetName": "test", "tableName": "film"})

# Aggregate winning predicates and count occurrences
for doc in documents:
    winning_predicates = doc.get("winningCandidates", {})
    for outer_key, inner_dict in winning_predicates.items():
        for inner_key, predicates in inner_dict.items():
            for predicate, score in predicates.items():
                aggregated_winning_predicates[(outer_key, inner_key)][predicate] += score
                predicate_counts[(outer_key, inner_key)][predicate] += 1

# Normalize the aggregated scores by the number of occurrences
normalized_winning_predicates = {}
for key, predicates in aggregated_winning_predicates.items():
    normalized_winning_predicates[key] = {predicate: round(score / predicate_counts[key][predicate], 3) for predicate, score in predicates.items()}

qids_predicates = set()
pair_to_predicates = {}
for pair in normalized_winning_predicates:
    top_10_predicates = sorted(normalized_winning_predicates[pair].items(), key=lambda x: x[1], reverse=True)[0:5]
    pair_to_predicates[pair] = {}
    for k, v in top_10_predicates:
        pair_to_predicates[pair][k] = v 
        qids_predicates.add(k)
        
qids_to_labels = await fetch_labels(list(qids_predicates))
new_pair_to_predicates = []
for pair, predicates in pair_to_predicates.items():
    source_column, target_column = pair
    new_predicates = []
    for k, v in predicates.items():
        new_predicates.append({"id": k, "label": qids_to_labels[k]["labels"].get("en"), "score": v})
    new_pair_to_predicates.append({
        "idSourceColumn": source_column,
        "idTargetColumn": target_column,
        "predicates": new_predicates
    })

# %%
new_pair_to_predicates
# Out:
# [{'idSourceColumn': '0',
#   'idTargetColumn': '1',
#   'predicates': [{'id': 'P57', 'label': 'director', 'score': 0.958},
#    {'id': 'P58', 'label': 'screenwriter', 'score': 0.489},
#    {'id': 'P162', 'label': 'producer', 'score': 0.367},
#    {'id': 'P161', 'label': 'cast member', 'score': 0.242},
#    {'id': 'P170', 'label': 'creator', 'score': 0.2}]},
#  {'idSourceColumn': '0',
#   'idTargetColumn': '2',
#   'predicates': [{'id': 'P1083', 'label': 'maximum capacity', 'score': 0.09},
#    {'id': 'P2047', 'label': 'duration', 'score': 0.071},
#    {'id': 'P1093', 'label': 'gross tonnage', 'score': 0.045},
#    {'id': 'P4519', 'label': 'payload mass', 'score': 0.029},
#    {'id': 'P2043', 'label': 'length', 'score': 0.018}]},
#  {'idSourceColumn': '0',
#   'idTargetColumn': '3',
#   'predicates': [{'id': 'P272', 'label': 'production company', 'score': 0.747},
#    {'id': 'P750', 'label': 'distributed by', 'score': 0.609},
#    {'id': 'P264', 'label': 'record label', 'score': 0.106},
#    {'id': 'P31', 'label': 'instance of', 'score': 0.066},
#    {'id': 'P175', 'label': 'performer', 'score': 0.062}]},
#  {'idSourceColumn': '0',
#   'idTargetColumn': '5',
#   'predicates': [{'id': 'P2142', 'label': 'box office', 'score': 0.976},
#    {'id': 'P2130', 'label': 'cost', 'score': 0.177},
#    {'id': 'P2769', 'label': 'budget', 'score': 0.002}]},
#  {'idSourceColumn': '1',
#   'idTargetColumn': '0',
#   'predicates': [{'id': 'P800', 'label': 'notable work', 'score': 0.159},
#    {'id': 'P527', 'label': 'has part(s)', 'score': 0.037}]},
#  {'idSourceColumn': '1',
#   'idTargetColumn': '2',
#   'predicates': [{'id': 'P8687',
#     'label': 'social media followers',
#     'score': 0.046},
#    {'id': 'P2044', 'label': 'elevation above sea level', 'score': 0.015},
#    {'id': 'P2048', 'label': 'height', 'score': 0.01},
#    {'id': 'P2047', 'label': 'duration', 'score': 0.007},
#    {'id': 'P2067', 'label': 'mass', 'score': 0.006}]},
#  {'idSourceColumn': '1',
#   'idTargetColumn': '3',
#   'predicates': [{'id': 'P449', 'label': 'original broadcaster', 'score': 0.1},
#    {'id': 'P750', 'label': 'distributed by', 'score': 0.075},
#    {'id': 'P272', 'label': 'production company', 'score': 0.07},
#    {'id': 'P101', 'label': 'field of work', 'score': 0.049},
#    {'id': 'P69', 'label': 'educated at', 'score': 0.047}]},
#  {'idSourceColumn': '3',
#   'idTargetColumn': '2',
#   'predicates': [{'id': 'P1128', 'label': 'employees', 'score': 0.205},
#    {'id': 'P1082', 'label': 'population', 'score': 0.057},
#    {'id': 'P1538', 'label': 'number of households', 'score': 0.026},
#    {'id': 'P10622', 'label': 'per capita income', 'score': 0.011},
#    {'id': 'P8687', 'label': 'social media followers', 'score': 0.005}]},
#  {'idSourceColumn': '3',
#   'idTargetColumn': '5',
#   'predicates': [{'id': 'P2295', 'label': 'net profit', 'score': 0.123},
#    {'id': 'P3362', 'label': 'operating income', 'score': 0.014},
#    {'id': 'P2226', 'label': 'market capitalization', 'score': 0.013},
#    {'id': 'P2139', 'label': 'total revenue', 'score': 0.01},
#    {'id': 'P2403', 'label': 'total assets', 'score': 0.005}]}]

# %%
aggregated_winning_candidates["0"]["Q11424"]/2
# Out:
# 0.9335

# %%
await lamAPI.labels(list(qids_types))
